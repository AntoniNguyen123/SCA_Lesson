# %% [markdown]
# # **🎬 Hollywood Data Analysis**
#
# ![cover image](https://drive.google.com/uc?id=1Q74k0jius6M_kWRf91zZIJ5BdLzMQpjh)
# ![holiwood.png](attachment:holiwood.png)
#
# ## **📃 Introduction**
#
# In this Notebook, we'll work with a real dataset about movies. It includes details like the movie title, release year, budget, gross earnings, and more.
#
# We'll cover the following tasks:
#
# * Adding new columns to the dataset by performing basic math operations like addition, subtraction, and division on existing columns.
# * Adding new columns to the dataset by comparing values using operations like less-than (<), greater-than (>), and equals (==) on existing columns.
# * Dropping single or multiple columns.
# * Slicing the dataset by conditins.
#
# Let's get started!

# %% [markdown]
# ## **1️⃣ Data overview**

# %% [markdown]
# ### **📥 Data loading**

# %% [markdown]
# **Pandas import**
#
# At the first, we need to import Pandas. Write the code to import Pandas in the code cell below.
#
# > ⚠️ Don't forget to use the alias that is regularly used by all Data Analysts to import Pandas library.

# %%
# Enter your code
import pandas as pd

# %% [markdown]
# **Loading data by URL**
#
# The data to work is located in CSV file by the following link: https://raw.githubusercontent.com/RusAbk/sca_datasets/main/movies.csv
#
# Read the given dataset into a pandas dataframe (usually has name `df`)

# %%
# Your code for loading data into dataframe
df = pd.read_csv("https://raw.githubusercontent.com/RusAbk/sca_datasets/main/movies.csv")

# %% [markdown]
# ### **👁️ The first sight**

# %% [markdown]
# **Columns**
#
# Also, it's a very common action at the beginning to output the list of all the columns in the dataframe.

# %%
# Your code showing the list of columns
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %% [markdown]
# **Data structure overview**
#
# Another common action is to check the data structure. Output an overview of the columns in the cell below.

# %%
# Your code showing dataframe columns' types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %% [markdown]
# **The first 5 rows**
#
# Before performing any operation with data, you need to take a look to ensure that everything is okay with the loaded data.
#
# In the cell below, write a code to output the first 5 rows of the dataframe.

# %%
# Your code showing the first 5 row
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %% [markdown]
# ### **📊 Basic descriptive statistics**

# %% [markdown]
# Show the basic descriptive statistics for the entire dataframe.

# %%
# Your code showing descriptive statistics for the dataframe
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %% [markdown]
# ## **2️⃣ Data operations**

# %% [markdown]
# ### **🤑 Create a new column revenue**
#
# Let's insert a new column called **"revenue"** into the dataframe.
#
# This column should show the difference between the values in the **"gross"** and **"budget"** columns.

# %%
# Enter your code
df['revenue'] = df['gross'] - df['budget']

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue
# 0   46998772.0        Warner Bros.    146.0   27998772.0
# 1   58853106.0   Columbia Pictures    104.0   54353106.0
# 2  538375067.0           Lucasfilm    124.0  520375067.0
# 3   83453539.0  Paramount Pictures     88.0   79953539.0
# 4   39846344.0      Orion Pictures     98.0   33846344.0

# %% [markdown]
# ### **% Create a new column `percentage_profit`**

# %% [markdown]
# Then let's create a new column named **"percentage_profit"** in the dataframe.
#
# We'll compute its values as the ratio of revenue to gross earnings, multiplied by 100 for each row.
#
# > 👉For instance, if the **gross earnings** are 200 USD and the **revenue** is 100 USD, the **percentage_profit** will be 50%
# >
# > `(100 / 200) * 100 = 50`

# %%
# Enter your code
df['percentage_profit'] = (df['revenue'] / df['gross']) * 100

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157

# %% [markdown]
# ### **💎 Create a new column `high_budget_movie`**

# %% [markdown]
# Introduce a new column named **"high_budget_movie"** into the dataframe.
#
# This column will mark each movie as `True` if its budget **exceeds 100 million**, or `False` if it does not.

# %%
# Enter your code
df['high_budget_movie'] = df['budget'] > 1000000000 #100_000_000

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit  \
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %% [markdown]
# ### **💪 Create a new column `successful_movie`**

# %% [markdown]
# Now let's append a new column to the dataframe called **"successful_movie"**.
#
# In this column, assign the value `True` if a movie's **percentage_profit** exceeds 50, and `False` otherwise.

# %%
# Enter your code
df['successful_movie'] = df['percentage_profit'] > 50

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit  \
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie
# 0              False              True
# 1              False              True
# 2              False              True
# 3              False              True
# 4              False              True

# %% [markdown]
# ### **🏆 High-Rated Movies**

# %% [markdown]
# Add a new column named **"high_rated_movie"** to the dataframe.
#
# If a **movie's score** exceeds 8, mark it as `True`; otherwise, mark it as `False`.

# %%
# Enter your code
df['high_rated_movie'] = df['score'] > 8

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime      revenue  percentage_profit  \
# 0   46998772.0        Warner Bros.    146.0   27998772.0          59.573412
# 1   58853106.0   Columbia Pictures    104.0   54353106.0          92.353845
# 2  538375067.0           Lucasfilm    124.0  520375067.0          96.656606
# 3   83453539.0  Paramount Pictures     88.0   79953539.0          95.806050
# 4   39846344.0      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie  high_rated_movie
# 0              False              True              True
# 1              False              True             False
# 2              False              True              True
# 3              False              True             False
# 4              False              True             False

# %% [markdown]
# ### **🆕 Create a new column `is_new_release`**

# %% [markdown]
# Let's add a new column called **"is_new_release"** to the dataframe.
#
# This column will be `True` if the value in the **"year"** column is **after 2020**, and `False` otherwise.

# %%
# Enter your code
df['is_new_release'] = df['year'] > 2020

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...      budget        gross  \
# 0             Stephen King  Jack Nicholson  ...  19000000.0   46998772.0
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   4500000.0   58853106.0
# 2           Leigh Brackett     Mark Hamill  ...  18000000.0  538375067.0
# 3             Jim Abrahams     Robert Hays  ...   3500000.0   83453539.0
# 4       Brian Doyle-Murray     Chevy Chase  ...   6000000.0   39846344.0
#
#               company runtime      revenue  percentage_profit  \
# 0        Warner Bros.   146.0   27998772.0          59.573412
# 1   Columbia Pictures   104.0   54353106.0          92.353845
# 2           Lucasfilm   124.0  520375067.0          96.656606
# 3  Paramount Pictures    88.0   79953539.0          95.806050
# 4      Orion Pictures    98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie  high_rated_movie  is_new_release
# 0              False              True              True           False
# 1              False              True             False           False
# 2              False              True              True           False
# 3              False              True             False           False
# 4              False              True             False           False
#
# [5 rows x 21 columns]

# %% [markdown]
# ### **⏳ Create a new column `is_long_movie`**

# %% [markdown]
# Add a new column named **"is_long_movie"** into the dataframe.
#
# If the value in the **"runtime"** column **exceeds 150 minut**es, assign `True`; otherwise, assign `False`.

# %%
# Enter your code
df['is_long_movie'] = df['runtime'] > 150

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...        gross  \
# 0             Stephen King  Jack Nicholson  ...   46998772.0
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   58853106.0
# 2           Leigh Brackett     Mark Hamill  ...  538375067.0
# 3             Jim Abrahams     Robert Hays  ...   83453539.0
# 4       Brian Doyle-Murray     Chevy Chase  ...   39846344.0
#
#               company  runtime      revenue  percentage_profit  \
# 0        Warner Bros.    146.0   27998772.0          59.573412
# 1   Columbia Pictures    104.0   54353106.0          92.353845
# 2           Lucasfilm    124.0  520375067.0          96.656606
# 3  Paramount Pictures     88.0   79953539.0          95.806050
# 4      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  successful_movie  high_rated_movie  is_new_release  \
# 0              False              True              True           False
# 1              False              True             False           False
# 2              False              True              True           False
# 3              False              True             False           False
# 4              False              True             False           False
#
#    is_long_movie
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 22 columns]

# %% [markdown]
# ### **📆 Age of Movies**

# %% [markdown]
# Create a new column named **age** to calculate the age of the movie in years.
#
# Find it by subtracting the year column from the current year.

# %%
# Your code
from datetime import datetime
current_year = datetime.now().year
df['age'] = current_year - df['year']

# %%
# Show the first 5 rows again to check
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...             company  runtime  \
# 0             Stephen King  Jack Nicholson  ...        Warner Bros.    146.0
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   Columbia Pictures    104.0
# 2           Leigh Brackett     Mark Hamill  ...           Lucasfilm    124.0
# 3             Jim Abrahams     Robert Hays  ...  Paramount Pictures     88.0
# 4       Brian Doyle-Murray     Chevy Chase  ...      Orion Pictures     98.0
#
#        revenue percentage_profit  high_budget_movie  successful_movie  \
# 0   27998772.0         59.573412              False              True
# 1   54353106.0         92.353845              False              True
# 2  520375067.0         96.656606              False              True
# 3   79953539.0         95.806050              False              True
# 4   33846344.0         84.942157              False              True
#
#    high_rated_movie  is_new_release  is_long_movie  age
# 0              True           False          False   45
# 1             False           False          False   45
# 2              True           False          False   45
# 3             False           False          False   45
# 4             False           False          False   45
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **3️⃣ Dataframe slicing**

# %% [markdown]
# ### **🥇 Top High-Rated Movies**

# %% [markdown]
# Create a new DataFrame named `top10_movies`, which should include the top 10 highly-rated movies.
#
# Sort this DataFrame based on the score column in descending order.

# %%
# Your code
top10_movies = df.sort_values(by='score', ascending=False).head(10)

# %% [markdown]
# ... and output them after (entire dataframe)

# %%
# Your code
top10_movies
# Out:
#                                                    name rating      genre  \
# 2443                           The Shawshank Redemption      R      Drama
# 5243                                    The Dark Knight  PG-13     Action
# 2247                                   Schindler's List      R  Biography
# 2444                                       Pulp Fiction      R      Crime
# 4245      The Lord of the Rings: The Return of the King  PG-13     Action
# 5643                                          Inception  PG-13     Action
# 3845  The Lord of the Rings: The Fellowship of the Ring  PG-13     Action
# 2445                                       Forrest Gump  PG-13      Drama
# 3444                                         Fight Club      R      Drama
# 4048              The Lord of the Rings: The Two Towers  PG-13     Action
#
#       year                           released  score      votes  \
# 2443  1994   October 14, 1994 (United States)    9.3  2400000.0
# 5243  2008      July 18, 2008 (United States)    9.0  2400000.0
# 2247  1993   February 4, 1994 (United States)    8.9  1200000.0
# 2444  1994   October 14, 1994 (United States)    8.9  1900000.0
# 4245  2003  December 17, 2003 (United States)    8.9  1700000.0
# 5643  2010      July 16, 2010 (United States)    8.8  2100000.0
# 3845  2001  December 19, 2001 (United States)    8.8  1700000.0
# 2445  1994       July 6, 1994 (United States)    8.8  1900000.0
# 3444  1999   October 15, 1999 (United States)    8.8  1900000.0
# 4048  2002  December 18, 2002 (United States)    8.7  1500000.0
#
#                director             writer               star  ...  \
# 2443     Frank Darabont       Stephen King        Tim Robbins  ...
# 5243  Christopher Nolan     Jonathan Nolan     Christian Bale  ...
# 2247   Steven Spielberg    Thomas Keneally        Liam Neeson  ...
# 2444  Quentin Tarantino  Quentin Tarantino      John Travolta  ...
# 4245      Peter Jackson     J.R.R. Tolkien        Elijah Wood  ...
# 5643  Christopher Nolan  Christopher Nolan  Leonardo DiCaprio  ...
# 3845      Peter Jackson     J.R.R. Tolkien        Elijah Wood  ...
# 2445    Robert Zemeckis      Winston Groom          Tom Hanks  ...
# 3444      David Fincher    Chuck Palahniuk          Brad Pitt  ...
# 4048      Peter Jackson     J.R.R. Tolkien        Elijah Wood  ...
#
#                         company  runtime       revenue percentage_profit  \
# 2443  Castle Rock Entertainment    142.0  3.817291e+06         13.246530
# 5243               Warner Bros.    152.0  8.209736e+08         81.609856
# 2247         Universal Pictures    195.0  3.001612e+08         93.171121
# 2444                    Miramax    154.0  2.059288e+08         96.260437
# 4245            New Line Cinema    201.0  1.052031e+09         91.797778
# 5643               Warner Bros.    148.0  6.768370e+08         80.880386
# 3845            New Line Cinema    178.0  8.046901e+08         89.640077
# 2445         Paramount Pictures    142.0  6.232261e+08         91.890610
# 3444          Fox 2000 Pictures    139.0  3.820970e+07         37.753003
# 4048            New Line Cinema    179.0  8.534951e+08         90.079104
#
#       high_budget_movie  successful_movie  high_rated_movie  is_new_release  \
# 2443              False             False              True           False
# 5243              False              True              True           False
# 2247              False              True              True           False
# 2444              False              True              True           False
# 4245              False              True              True           False
# 5643              False              True              True           False
# 3845              False              True              True           False
# 2445              False              True              True           False
# 3444              False             False              True           False
# 4048              False              True              True           False
#
#       is_long_movie  age
# 2443          False   31
# 5243           True   17
# 2247           True   32
# 2444           True   31
# 4245           True   22
# 5643          False   15
# 3845           True   24
# 2445          False   31
# 3444          False   26
# 4048           True   23
#
# [10 rows x 23 columns]

# %% [markdown]
# ### **💎 Only successful ones**

# %% [markdown]
# Create a new DataFrame named **successful_movies** containing only the movies that are successful according to the **'successful_movie'** column values.

# %%
# Your code
# Create the 'revenue' column

successful_movies = df[df['successful_movie']]

# %%
# Show the first 5 rows of the nes dataframe to check the result
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...             company  runtime  \
# 0             Stephen King  Jack Nicholson  ...        Warner Bros.    146.0
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   Columbia Pictures    104.0
# 2           Leigh Brackett     Mark Hamill  ...           Lucasfilm    124.0
# 3             Jim Abrahams     Robert Hays  ...  Paramount Pictures     88.0
# 4       Brian Doyle-Murray     Chevy Chase  ...      Orion Pictures     98.0
#
#        revenue percentage_profit  high_budget_movie  successful_movie  \
# 0   27998772.0         59.573412              False              True
# 1   54353106.0         92.353845              False              True
# 2  520375067.0         96.656606              False              True
# 3   79953539.0         95.806050              False              True
# 4   33846344.0         84.942157              False              True
#
#    high_rated_movie  is_new_release  is_long_movie  age
# 0              True           False          False   45
# 1             False           False          False   45
# 2              True           False          False   45
# 3             False           False          False   45
# 4             False           False          False   45
#
# [5 rows x 23 columns]

# %% [markdown]
# As the column successful_movie is useles for the created dataframe, it's good idea to remove it. Let's do this.

# %%
# Your code
successful_movies = successful_movies.drop(columns=['successful_movie'])

# %%
# Show the first 5 rows of the nes dataframe to check the result
successful_movies.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ...        gross  \
# 0             Stephen King  Jack Nicholson  ...   46998772.0
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   58853106.0
# 2           Leigh Brackett     Mark Hamill  ...  538375067.0
# 3             Jim Abrahams     Robert Hays  ...   83453539.0
# 4       Brian Doyle-Murray     Chevy Chase  ...   39846344.0
#
#               company  runtime      revenue  percentage_profit  \
# 0        Warner Bros.    146.0   27998772.0          59.573412
# 1   Columbia Pictures    104.0   54353106.0          92.353845
# 2           Lucasfilm    124.0  520375067.0          96.656606
# 3  Paramount Pictures     88.0   79953539.0          95.806050
# 4      Orion Pictures     98.0   33846344.0          84.942157
#
#    high_budget_movie  high_rated_movie  is_new_release  is_long_movie  age
# 0              False              True           False          False   45
# 1              False             False           False          False   45
# 2              False              True           False          False   45
# 3              False             False           False          False   45
# 4              False             False           False          False   45
#
# [5 rows x 22 columns]

# %% [markdown]
# ### **🤖 Sci-Fi Blockbusters**

# %% [markdown]
# Create a new DataFrame named **sci_fi_blockbusters** containing movies that are **'Sci-Fi'** genre and have a **gross greater than $150 million**.

# %%
# Your code
sci_fi_blockbusters = df[(df['genre'] == 'Sci-Fi') & (df['gross'] > 150_000_000)]

# %%
# Show the first 5 rows of the nes dataframe to check the result
sci_fi_blockbusters
# Out:
#            name rating   genre  year                        released  score  \
# 5876  Limitless  PG-13  Sci-Fi  2011  March 18, 2011 (United States)    7.4
#
#          votes     director        writer            star  ...  \
# 5876  538000.0  Neil Burger  Leslie Dixon  Bradley Cooper  ...
#
#                company  runtime      revenue percentage_profit  \
# 5876  Relativity Media    105.0  134849455.0         83.317831
#
#       high_budget_movie  successful_movie  high_rated_movie  is_new_release  \
# 5876              False              True             False           False
#
#       is_long_movie  age
# 5876          False   14
#
# [1 rows x 23 columns]

# %% [markdown]
# ### **🏖️ Movies Released in Summer**

# %% [markdown]
# Create a new DataFrame containing movies released in June, July, or August.
#
# Store the result in dataframe `summer_movies`.
#
# > 🏋️‍♀️ Please **note that this task cannot be fully solved using the tools and constructions we have covered in the lecture**.
# >
# > You need to demonstrate resourcefulness and show your skill in searching for information on the internet.

# %%
# Your code
# Check if 'released' column exists before proceeding
if 'released' in df.columns:
    # Extract the first 3 letters (month abbreviation) from the 'released' column
    df['month'] = df['released'].str[:3]

    if 'month' in df.columns:
        summer_movies = df[df['month'].isin(['Jun', 'Jul', 'Aug'])]  # Use month abbreviations
        print(summer_movies)
    else:
        print("Error: 'month' column not found in the DataFrame.")
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7639                              Round of Your Life        NaN     Family
# 7642                                A Brother's Love        NaN      Drama
# 7652                               The Eight Hundred  Not Rated     Action
# 7656                                           Tulsa      PG-13     Comedy
# 7667                                       Tee em el        NaN     Horror
#
#       year                         released  score      votes  \
# 0     1980    June 13, 1980 (United States)    8.4   927000.0
# 1     1980     July 2, 1980 (United States)    5.8    65000.0
# 2     1980    June 20, 1980 (United States)    8.7  1200000.0
# 3     1980     July 2, 1980 (United States)    7.7   221000.0
# 4     1980    July 25, 1980 (United States)    7.3   108000.0
# ...    ...                              ...    ...        ...
# 7639  2019    June 21, 2019 (United States)    4.6      150.0
# 7642  2019            June 7, 2019 (Canada)    6.8      869.0
# 7652  2020  August 28, 2020 (United States)    6.8     3700.0
# 7656  2020     June 3, 2020 (United States)    5.0      294.0
# 7667  2020  August 19, 2020 (United States)    5.7        7.0
#
#                 director                   writer                  star  ...  \
# 0        Stanley Kubrick             Stephen King        Jack Nicholson  ...
# 1         Randal Kleiser  Henry De Vere Stacpoole        Brooke Shields  ...
# 2         Irvin Kershner           Leigh Brackett           Mark Hamill  ...
# 3           Jim Abrahams             Jim Abrahams           Robert Hays  ...
# 4           Harold Ramis       Brian Doyle-Murray           Chevy Chase  ...
# ...                  ...                      ...                   ...  ...
# 7639  Dylan Thomas Ellis             Tim Ogletree            Cole Allen  ...
# 7642        Monia Chokri             Monia Chokri  Anne-Élisabeth Bossé  ...
# 7652             Hu Guan                  Hu Guan       Zhi-zhong Huang  ...
# 7656         Scott Pryor              Scott Pryor           Scott Pryor  ...
# 7667        Pereko Mosia             Pereko Mosia      Siyabonga Mabaso  ...
#
#      runtime      revenue  percentage_profit high_budget_movie  \
# 0      146.0   27998772.0          59.573412             False
# 1      104.0   54353106.0          92.353845             False
# 2      124.0  520375067.0          96.656606             False
# 3       88.0   79953539.0          95.806050             False
# 4       98.0   33846344.0          84.942157             False
# ...      ...          ...                ...               ...
# 7639    91.0          NaN                NaN             False
# 7642   117.0          NaN                NaN             False
# 7652   149.0  381421559.0          82.662275             False
# 7656   120.0          NaN                NaN             False
# 7667   102.0          NaN                NaN             False
#
#       successful_movie  high_rated_movie  is_new_release  is_long_movie  age  \
# 0                 True              True           False          False   45
# 1                 True             False           False          False   45
# 2                 True              True           False          False   45
# 3                 True             False           False          False   45
# 4                 True             False           False          False   45
# ...                ...               ...             ...            ...  ...
# 7639             False             False           False          False    6
# 7642             False             False           False          False    6
# 7652              True             False           False          False    5
# 7656             False             False           False          False    5
# 7667             False             False           False          False    5
#
#       month
# 0       Jun
# 1       Jul
# 2       Jun
# 3       Jul
# 4       Jul
# ...     ...
# 7639    Jun
# 7642    Jun
# 7652    Aug
# 7656    Jun
# 7667    Aug
#
# [1883 rows x 24 columns]

# %%
# Show the first 5 rows of the nes dataframe to check the result
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star  ... runtime      revenue  \
# 0             Stephen King  Jack Nicholson  ...   146.0   27998772.0
# 1  Henry De Vere Stacpoole  Brooke Shields  ...   104.0   54353106.0
# 2           Leigh Brackett     Mark Hamill  ...   124.0  520375067.0
# 3             Jim Abrahams     Robert Hays  ...    88.0   79953539.0
# 4       Brian Doyle-Murray     Chevy Chase  ...    98.0   33846344.0
#
#    percentage_profit high_budget_movie  successful_movie  high_rated_movie  \
# 0          59.573412             False              True              True
# 1          92.353845             False              True             False
# 2          96.656606             False              True              True
# 3          95.806050             False              True             False
# 4          84.942157             False              True             False
#
#    is_new_release  is_long_movie  age  month
# 0           False          False   45    Jun
# 1           False          False   45    Jul
# 2           False          False   45    Jun
# 3           False          False   45    Jul
# 4           False          False   45    Jul
#
# [5 rows x 24 columns]
